# %%
import matplotlib.pyplot as plt
l =[25,46,57,25,13,29,39,46,99,22,12,14,16,55,6,46,52,55,150]
l1 = [2,3,56,44,22,3,69,44,12,23,45,78]
plots = [l,l1]
plt.boxplot(plots)
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
plt.boxplot(df["Annual Salary"])
plt.show()

# %%
x= [30,40,68,75,56,47,45,34,23,43,74,7,90]
plt.hist(x,bins = 30,edgecolor = "black")
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
plt.hist(df["Age"],bins = 15)
plt.show()

# %%
a =[20,30,40,50,30,22,5,6,66,77,87,98,32,76]
plt.violinplot(a,showmedians = True)
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
plt.violinplot(df["Age"])
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
plt.violinplot(df["Annual Salary"])
plt.show()
