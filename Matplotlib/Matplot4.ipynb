# %%
import matplotlib.pyplot as plt
x =[10,20,34,56,43,56,76,45,32,67,88,99,2,5]
plt.stem(x)
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
df2 = (df.head (50))
plt.stem(df2["Age"])
plt.plot(df2["Age"])
plt.show()

# %%
days =[1,2,3,4,5,6,7]
nop1 =[5,10,30,20,33,45,34]
nop2 =[5,6,77,44,56,33,55]
nop3 =[10,12,21,32,43,65,66]
plt.stackplot(days,nop1,nop2,nop3,labels = ["week1","week2","week3"])
plt.legend()
plt.show()

# %%
x = ["day1","day2","day3","day4","day5"]
y =[30,40,25,30,21]
plt.step(x,y,where = "post")
plt.show()
