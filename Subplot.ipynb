# %%
import matplotlib.pyplot as plt
x= [1,2,3,4,5]
y =[45,67,33,67,54]
y1 =[41,32,45,67,87]
y3 =[43,39,76,21,32]

plt.figure(figsize = [5,3] )
plt.plot(x,y, label = "male")
plt.plot(x,y1, label = "female")
plt.plot(x,y3, label = "kids")

plt.legend(bbox_to_anchor= (0.7,1.4))
plt.show()

# %%
x =[1,2,3,4,5]
y =[45,32,45,32,67]
plt.subplot(1,3,1)
plt.plot(x,y)

x = [5,6,7,8,9]
y = [45,67,54,32,56]
plt.plot(x,y)
plt.subplot(1,3,2)

x = [2,4,6,8,10]
y = [54,43,76,82,65]
plt.plot(x,y)
plt.subplot(1,3,2)
